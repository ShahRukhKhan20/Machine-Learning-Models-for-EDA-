# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_excel("FinTech_ChainAudit.xlsx")

# %%
df.head()
# Out:
#   Transaction_ID        Date  Wallet_Type Tran_Type Blockchain   Amount   \
# 0      TXN100002  2025-07-22     Customer      Swap        BSC  20555.75
# 1      TXN100003  2025-12-27          NaN   Staking     Solana  25571.60
# 2      TXN100004  2025-07-27  Operational      DeFi    Polygon  40219.77
# 3      TXN100005  2025-08-27     Customer    saving    Polygon  44989.59
# 4      TXN100006  2025-12-16     Treasury      DeFi     Solana       NaN
#
#    Gas_Fee_USD  Customer_Type       Region  Processing_Time_sec  \
# 0        32.61            VIP      America                203.0
# 1        16.49  Institutional       Europe                152.0
# 2        39.93         Retail       Europe                 27.0
# 3        18.03            VIP       Europe                177.0
# 4        77.33  Institutional  Middle East                202.0
#
#    Fraud_Risk_Score Compliance_Status Marketing_Campaign  \
# 0             38.98              Pass                Yes
# 1             56.57              Pass                 No
# 2             82.62            Review                Yes
# 3              1.05              Pass                 No
# 4             29.83            Review                 No
#
#    Number_of_Active_Customers  Daily_Revenue_USD      Sales
# 0                       929.0           12870.12    24666.9
# 1                       519.0            5099.70   30685.92
# 2                      2002.0           22341.17  48263.724
# 3                      3205.0           31676.08      -5000
# 4                      3439.0           24182.19        NaN

# %%
df.tail()
# Out:
#      Transaction_ID        Date Wallet_Type Tran_Type Blockchain   Amount   \
# 1996      TXN101998  2025-02-20    Employee   Staking    Polygon  29301.51
# 1997      TXN101999  2025-02-21    Employee      DeFi   Ethereum  42861.13
# 1998      TXN102000  2025-08-14    Customer       NFT     Solana  33225.74
# 1999      TXN102001  2025-09-11    Employee       NFT    Polygon  30977.11
# 2000      TXN100002  2025-07-22    Customer      Swap        BSC  20555.75
#
#       Gas_Fee_USD Customer_Type       Region  Processing_Time_sec  \
# 1996        92.99        Retail      America                181.0
# 1997        44.11           VIP  Middle East                222.0
# 1998        82.92        Retail         Asia                 67.0
# 1999       100.98           VIP      America                255.0
# 2000        32.61           VIP      America                203.0
#
#       Fraud_Risk_Score Compliance_Status Marketing_Campaign  \
# 1996             94.83              Fail                 No
# 1997             39.01            Review                 No
# 1998             61.01              Fail                Yes
# 1999             73.39              Pass                 No
# 2000             38.98              Pass                Yes
#
#       Number_of_Active_Customers  Daily_Revenue_USD      Sales
# 1996                       820.0            3953.46  35161.812
# 1997                      4650.0           36834.23  51433.356
# 1998                      1856.0           26083.71  39870.888
# 1999                      2633.0           23772.50  37172.532
# 2000                       929.0           12870.12    24666.9

# %% [markdown]
# ## DATA UNDERSTANDING

# %%
df.shape
# Out:
# (2001, 16)

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Wallet_Type', 'Tran_Type', 'Blockchain',
#        'Amount ', 'Gas_Fee_USD', 'Customer_Type', 'Region',
#        'Processing_Time_sec', 'Fraud_Risk_Score', 'Compliance_Status',
#        'Marketing_Campaign', 'Number_of_Active_Customers', 'Daily_Revenue_USD',
#        'Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Transaction_ID              1996 non-null   object
#  1   Date                        1982 non-null   object
#  2   Wallet_Type                 1922 non-null   object
#  3   Tran_Type                   1975 non-null   object
#  4   Blockchain                  1983 non-null   object
#  5   Amount                      1990 non-null   float64
#  6   Gas_Fee_USD                 1975 non-null   float64
#  7   Customer_Type               1981 non-null   object
#  8   Region                      1974 non-null   object
#  9   Processing_Time_sec         1989 non-null   float64
#  10  Fraud_Risk_Score            1986 non-null   float64
#  11  Compliance_Status           1972 non-null   object
#  12  Marketing_Campaign          1992 non-null   object
#  13  Number_of_Active_Customers  1981 non-null   float64
#  14  Daily_Revenue_USD           1987 non-null   float64
#  15  Sales                       1991 non-null   object
# dtypes: float64(6), object(10)
# memory usage: 250.2+ KB

# %%
df.dtypes
# Out:
# Transaction_ID                 object
# Date                           object
# Wallet_Type                    object
# Tran_Type                      object
# Blockchain                     object
# Amount                        float64
# Gas_Fee_USD                   float64
# Customer_Type                  object
# Region                         object
# Processing_Time_sec           float64
# Fraud_Risk_Score              float64
# Compliance_Status              object
# Marketing_Campaign             object
# Number_of_Active_Customers    float64
# Daily_Revenue_USD             float64
# Sales                          object
# dtype: object

# %%
df.describe()
# Out:
#             Amount   Gas_Fee_USD  Processing_Time_sec  Fraud_Risk_Score  \
# count   1990.000000  1975.000000          1989.000000       1986.000000
# mean   24990.586317    59.411241           153.158371         48.763243
# std    14346.120987    35.264629            85.973187         28.973853
# min   -15000.000000     0.650000             5.000000          0.060000
# 25%    12187.292500    27.960000            79.000000         23.630000
# 50%    24819.780000    58.970000           154.000000         47.885000
# 75%    37376.755000    90.200000           226.000000         73.217500
# max    49979.940000   119.970000           300.000000         99.900000
#
#        Number_of_Active_Customers  Daily_Revenue_USD
# count                 1981.000000        1987.000000
# mean                  2552.363958       22372.492652
# std                   1425.366197       10412.518021
# min                     51.000000         235.680000
# 25%                   1353.000000       14403.990000
# 50%                   2549.000000       22386.230000
# 75%                   3780.000000       30141.950000
# max                   6676.000000       50623.470000

# %%
df.describe(include="all")
# Out:
#        Transaction_ID        Date Wallet_Type Tran_Type Blockchain  \
# count            1996        1982        1922      1975       1983
# unique           1995         365           5         8          4
# top         TXN100002  2025-03-06    Employee      Swap        BSC
# freq                2          15         513       307        546
# mean              NaN         NaN         NaN       NaN        NaN
# std               NaN         NaN         NaN       NaN        NaN
# min               NaN         NaN         NaN       NaN        NaN
# 25%               NaN         NaN         NaN       NaN        NaN
# 50%               NaN         NaN         NaN       NaN        NaN
# 75%               NaN         NaN         NaN       NaN        NaN
# max               NaN         NaN         NaN       NaN        NaN
#
#              Amount   Gas_Fee_USD Customer_Type   Region  Processing_Time_sec  \
# count    1990.000000  1975.000000          1981     1974          1989.000000
# unique           NaN          NaN             3        4                  NaN
# top              NaN          NaN           VIP  America                  NaN
# freq             NaN          NaN           675      507                  NaN
# mean    24990.586317    59.411241           NaN      NaN           153.158371
# std     14346.120987    35.264629           NaN      NaN            85.973187
# min    -15000.000000     0.650000           NaN      NaN             5.000000
# 25%     12187.292500    27.960000           NaN      NaN            79.000000
# 50%     24819.780000    58.970000           NaN      NaN           154.000000
# 75%     37376.755000    90.200000           NaN      NaN           226.000000
# max     49979.940000   119.970000           NaN      NaN           300.000000
#
#         Fraud_Risk_Score Compliance_Status Marketing_Campaign  \
# count        1986.000000              1972               1992
# unique               NaN                 3                  2
# top                  NaN              Pass                Yes
# freq                 NaN               665               1002
# mean           48.763243               NaN                NaN
# std            28.973853               NaN                NaN
# min             0.060000               NaN                NaN
# 25%            23.630000               NaN                NaN
# 50%            47.885000               NaN                NaN
# 75%            73.217500               NaN                NaN
# max            99.900000               NaN                NaN
#
#         Number_of_Active_Customers  Daily_Revenue_USD    Sales
# count                  1981.000000        1987.000000   1991.0
# unique                         NaN                NaN   1988.0
# top                            NaN                NaN  24666.9
# freq                           NaN                NaN      2.0
# mean                   2552.363958       22372.492652      NaN
# std                    1425.366197       10412.518021      NaN
# min                      51.000000         235.680000      NaN
# 25%                    1353.000000       14403.990000      NaN
# 50%                    2549.000000       22386.230000      NaN
# 75%                    3780.000000       30141.950000      NaN
# max                    6676.000000       50623.470000      NaN

# %%
df["Wallet_Type"].unique()
# Out:
# array(['Customer', nan, 'Operational', 'Treasury', 150, 'Employee'],
#       dtype=object)

# %% [markdown]
# ## DATA PREPROCESSING

# %%
df.isnull().sum()
# Out:
# Transaction_ID                 5
# Date                          19
# Wallet_Type                   79
# Tran_Type                     26
# Blockchain                    18
# Amount                        11
# Gas_Fee_USD                   26
# Customer_Type                 20
# Region                        27
# Processing_Time_sec           12
# Fraud_Risk_Score              15
# Compliance_Status             29
# Marketing_Campaign             9
# Number_of_Active_Customers    20
# Daily_Revenue_USD             14
# Sales                         10
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Transaction_ID                0.249875
# Date                          0.949525
# Wallet_Type                   3.948026
# Tran_Type                     1.299350
# Blockchain                    0.899550
# Amount                        0.549725
# Gas_Fee_USD                   1.299350
# Customer_Type                 0.999500
# Region                        1.349325
# Processing_Time_sec           0.599700
# Fraud_Risk_Score              0.749625
# Compliance_Status             1.449275
# Marketing_Campaign            0.449775
# Number_of_Active_Customers    0.999500
# Daily_Revenue_USD             0.699650
# Sales                         0.499750
# dtype: float64

# %%
df[df.select_dtypes(include="number").columns] = df.select_dtypes(include="number").fillna(df.select_dtypes(include="number").mean())

# %%
df[df.select_dtypes(include="object").columns] = df.select_dtypes(include="object").fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# Transaction_ID                0
# Date                          0
# Wallet_Type                   0
# Tran_Type                     0
# Blockchain                    0
# Amount                        0
# Gas_Fee_USD                   0
# Customer_Type                 0
# Region                        0
# Processing_Time_sec           0
# Fraud_Risk_Score              0
# Compliance_Status             0
# Marketing_Campaign            0
# Number_of_Active_Customers    0
# Daily_Revenue_USD             0
# Sales                         0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#      Transaction_ID        Date Wallet_Type Tran_Type Blockchain   Amount   \
# 2000      TXN100002  2025-07-22    Customer      Swap        BSC  20555.75
#
#       Gas_Fee_USD Customer_Type   Region  Processing_Time_sec  \
# 2000        32.61           VIP  America                203.0
#
#       Fraud_Risk_Score Compliance_Status Marketing_Campaign  \
# 2000             38.98              Pass                Yes
#
#       Number_of_Active_Customers  Daily_Revenue_USD    Sales
# 2000                       929.0           12870.12  24666.9

# %%
remove_values= df.drop_duplicates()

# %%
df.dtypes
# Out:
# Transaction_ID                 object
# Date                           object
# Wallet_Type                    object
# Tran_Type                      object
# Blockchain                     object
# Amount                        float64
# Gas_Fee_USD                   float64
# Customer_Type                  object
# Region                         object
# Processing_Time_sec           float64
# Fraud_Risk_Score              float64
# Compliance_Status              object
# Marketing_Campaign             object
# Number_of_Active_Customers    float64
# Daily_Revenue_USD             float64
# Sales                          object
# dtype: object

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS (EDA)
#
# Histogram

# %%
df["Sales"] = pd.to_numeric(df["Sales"], errors="coerce")

# %%
df["Sales"] = df["Sales"].fillna(df["Sales"].median())

# %%
df["Sales"].hist()

plt.show()

# %%
df = df.apply(lambda x: pd.to_numeric(x, errors="ignore"))

# %%
df[df.select_dtypes(include="number").columns] = df.select_dtypes(include="number").fillna(df.select_dtypes(include="number").median())

# %%
df.select_dtypes(include="number").hist(figsize=(15, 12))
plt.show()

# %% [markdown]
# ### Distribution plot

# %%
for column in df.select_dtypes(include="number").columns:
    sns.histplot(df[column], kde=True)
    plt.show()

# %% [markdown]
# ### BAR CHART

# %%
sns.countplot(x="Blockchain", data=df)

plt.show()

# %% [markdown]
# ### PIE CHART

# %%
df["Region"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ### Out Liers

# %%
sns.boxplot(x=df["Daily_Revenue_USD"])

plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(
    x="Daily_Revenue_USD",
    y="Sales",
    data=df
)

plt.show()

# %% [markdown]
# ### Corelation Matirx

# %%
df.select_dtypes(include="number").corr()
# Out:
#                              Amount   Gas_Fee_USD  Processing_Time_sec  \
# Amount                      1.000000     0.025199             0.039456
# Gas_Fee_USD                 0.025199     1.000000            -0.014022
# Processing_Time_sec         0.039456    -0.014022             1.000000
# Fraud_Risk_Score            0.023433    -0.013304             0.026082
# Number_of_Active_Customers  0.014380    -0.019980            -0.009885
# Daily_Revenue_USD           0.238046    -0.073515            -0.002356
# Sales                       0.014842    -0.021662             0.017769
#
#                             Fraud_Risk_Score  Number_of_Active_Customers  \
# Amount                              0.023433                    0.014380
# Gas_Fee_USD                        -0.013304                   -0.019980
# Processing_Time_sec                 0.026082                   -0.009885
# Fraud_Risk_Score                    1.000000                    0.010349
# Number_of_Active_Customers          0.010349                    1.000000
# Daily_Revenue_USD                  -0.004446                    0.837843
# Sales                              -0.002609                   -0.003579
#
#                             Daily_Revenue_USD     Sales
# Amount                               0.238046  0.014842
# Gas_Fee_USD                         -0.073515 -0.021662
# Processing_Time_sec                 -0.002356  0.017769
# Fraud_Risk_Score                    -0.004446 -0.002609
# Number_of_Active_Customers           0.837843 -0.003579
# Daily_Revenue_USD                    1.000000 -0.002432
# Sales                               -0.002432  1.000000

# %% [markdown]
# ### HeatMap

# %%
correlation = df.select_dtypes(include="number").corr()

sns.heatmap(correlation, annot=True)

plt.show()

# %%
df.columns = df.columns.str.strip()

# %% [markdown]
# ### DEFINE X AND Y VARIBALES

# %%
X = df[["Amount","Gas_Fee_USD","Daily_Revenue_USD"]]

y = df["Sales"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
model = DecisionTreeRegressor(random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
predictions = model.predict(X_test)

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 1657280.9851571068

# %%
mean_squared_error(y_test, predictions)
# Out:
# 1078586936496047.1

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 32841847.33683608

# %%
r2_score(y_test, predictions)
# Out:
# -0.002568958295545709

# %%
pd.DataFrame({
    "Variable": X.columns,
    "Importance": model.feature_importances_
})
# Out:
#             Variable  Importance
# 0             Amount    0.364422
# 1        Gas_Fee_USD    0.635553
# 2  Daily_Revenue_USD    0.000025

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(15,8))

plot_tree(
    model,
    feature_names=X.columns,
    filled=True
)

plt.show()

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(15,8))

plot_tree(
    model,
    feature_names=X.columns,
    filled=True,
    max_depth=3
)

plt.show()
